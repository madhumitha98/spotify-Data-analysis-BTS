# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials(client_id="a00833111fcf4d8bba50b6464f1a260d", client_secret="7422bccedaea480b84fd72a43beb6da5")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
for i in range(0,1000,50):
    track_results = sp.search(q = 'artist:BTS', type = 'track', limit = 50, offset = i)
    
print(track_results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3ABTS&type=track&offset=950&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26c5B9yK2GiYUe8H7zPYny'}, 'href': 'https://api.spotify.com/v1/artists/26c5B9yK2GiYUe8H7zPYny', 'id': '26c5B9yK2GiYUe8H7zPYny', 'name': 'BTS Exclusive', 'type': 'artist', 'uri': 'spotify:artist:26c5B9yK2GiYUe8H7zPYny'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'K
# ...

# %%
artist_name = []
track_name =[]
track_popularity = []
track_id = []
artist_id = []

for i in range(0,1000,50):
    track_results = sp.search(q = 'artist:BTS', type = 'track', limit = 50, offset = i)
    
    for i, t in enumerate(track_results['tracks']['items']):
        
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
import pandas as pd

data = pd.DataFrame({'artistName': artist_name, "artistId": artist_id, "trackName": track_name, "trackId": track_id, "Popularity": track_popularity})

BTS_top_5 = data.head()

BTS_top_5
# Out:
#   artistName                artistId    trackName                 trackId  \
# 0        BTS  3Nrfpe0tUJi4K4DXYWgMUX  Yet To Come  10SRMwb9EuVS1K9rYsBfHQ
# 1        BTS  3Nrfpe0tUJi4K4DXYWgMUX      Run BTS  69xohKu8C1fsflYAiSNbwM
# 2        BTS  3Nrfpe0tUJi4K4DXYWgMUX    For Youth  4JzCFEc3O2UEdjKzevvFH5
# 3        BTS  3Nrfpe0tUJi4K4DXYWgMUX     Dynamite  5QDLhrAOJJdNAmCTJ8xMyW
# 4        BTS  3Nrfpe0tUJi4K4DXYWgMUX  Born Singer  1IthE5GNiRzFN5CVaCa445
#
#    Popularity
# 0          93
# 1          89
# 2          85
# 3          87
# 4          84

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.pie(BTS_top_5["Popularity"], labels = BTS_top_5["trackName"])
plt.show()
